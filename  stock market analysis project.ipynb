# %%
import pandas as pd
from pandas_datareader import data,wb
from datetime import date
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
# %matplotlib inline

# %%
import yfinance as yf
start_date='1990-01-01'
end_date='2022-01-01'
symbols=['MSFT','AMZN','AAPL','GOOG','META']
stock=yf.download(symbols,start_date,end_date)
stock.tail()
# Out:
# [*********************100%***********************]  5 of 5 completed
#                             Adj Close                                      \
#                                  AAPL        AMZN        GOOG        META
# Date
# 2021-12-27 00:00:00-05:00  179.289444  169.669495  148.063995  346.179993
# 2021-12-28 00:00:00-05:00  178.255447  170.660995  146.447998  346.220001
# 2021-12-29 00:00:00-05:00  178.344925  169.201004  146.504501  342.940002
# 2021-12-30 00:00:00-05:00  177.171722  168.644501  146.002502  344.359985
# 2021-12-31 00:00:00-05:00  176.545364  166.716995  144.679504  336.350006
#
#                                             Close                          \
#                                  MSFT        AAPL        AMZN        GOOG
# Date
# 2021-12-27 00:00:00-05:00  339.270996  180.330002  169.669495  148.063995
# 2021-12-28 00:00:00-05:00  338.082123  179.289993  170.660995  146.447998
# ...

# %%
# Stock price
adj_date = stock["Adj Close"]
adj_date.plot()
plt.title("Tech Stocks Adjusted Price")
plt.xlabel("Date")
plt.ylabel("Adjusted Closing Price Over Time")
plt.grid(True)
plt.show()

# %%
#stock price of Tech
fig = plt.figure(figsize=(20, 10))
ax1 = plt.subplot(2, 3, 1)
plt.plot(adj_date['MSFT'], color='blue')
plt.title('Microsoft')
plt.xlabel('Date')
plt.ylabel("Adj Close")
#Amazon
ax2 = plt.subplot(2, 3, 2)
plt.plot(adj_date['AMZN'], color='orange')
plt.title('Amazon')
plt.xlabel('Date')
plt.ylabel("Adj Close")
#Apple
ax3 = plt.subplot(2, 3, 3)
plt.plot(adj_date['AAPL'], color='green')
plt.title('Apple')
plt.xlabel('Date')
plt.ylabel("Adj Close")
#Google
ax4 = plt.subplot(2, 3, 4)
plt.plot(adj_date['GOOG'], color='red')
plt.title('Google')
plt.xlabel('Date')
plt.ylabel("Adj Close")
#Meta
ax5 = plt.subplot(2, 3, 5)
plt.plot(adj_date['META'], color='black')
plt.title('Meta')
plt.xlabel('Date')
plt.ylabel("Adj Close")
plt.show()

# %%
# Simple rate of return
daily_return = adj_date.pct_change()
daily_return.plot()
plt.title("Daily Simple Rate of Return")
plt.xlabel("Date")
plt.ylabel("Rate of Return")
plt.grid(True)
plt.show()

# %%
# Daily Return
fig = plt.figure(figsize=(20, 10))
ax1 = plt.subplot(2, 3, 1)
plt.plot(daily_return['MSFT'], color='green')
plt.title('Microsoft')
plt.xlabel('Date')
plt.ylabel('Daily Return')
#Amazon
ax2 = plt.subplot(2, 3, 2)
plt.plot(daily_return['AMZN'], color='red')
plt.title('Amazon')
plt.xlabel('Date')
plt.ylabel('Daily Return')
#Apple
ax3 = plt.subplot(2, 3, 3)
plt.plot(daily_return['AAPL'], color='orange')
plt.title('Apple')
plt.xlabel('Date')
plt.ylabel('Daily Return')
#Google
ax4 = plt.subplot(2, 3, 4)
plt.plot(daily_return['GOOG'], color='blue')
plt.title('Google')
plt.xlabel('Date')
plt.ylabel('Daily Return')
#Meta
ax5 = plt.subplot(2, 3, 5)
plt.plot(daily_return['META'], color='black')
plt.title('Meta')
plt.xlabel('Date')
plt.ylabel('Daily Return')
plt.show()

# %%
# Mean rates of return
mean_returns = adj_date.pct_change().mean().plot(kind = 'bar', figsize = (8, 4))
plt.title("Mean rate of returns")
plt.xlabel("Symbols")
plt.ylabel("Mean Rate")
plt.show()

# %%
# Variances of the returns
variance_returns = adj_date.var()
variance_returns.plot()
plt.title("Variances of the retuns")
plt.xlabel("Symbols")
plt.ylabel("Variances")
plt.grid(True)
plt.show()

# %%
# Standard deviation of the returns
std_returns = daily_return.std()
std_returns.plot()
plt.title("Standard deviation of the returns")
plt.xlabel("Symbols")
plt.ylabel("Standard deviation")
plt.grid(True)
plt.show()

# %%
# Correlation between the tech stock
import seaborn as sns
corr_data =adj_date.pct_change().corr(method='pearson')
sns.heatmap(corr_data, annot=True, cmap="summer")
plt.title('Correlation of stock return')
plt.show()

# %%
import yfinance
import plotly.graph_objects as go

meta = yfinance.Ticker('META')
hist = meta.history(period='3y')
fig = go.Figure(data=go.Scatter(x=hist.index,y=hist['Close'], mode='lines'))
fig.show()
# Out:
# <div>                            <div id="f8442fe4-7e86-49b7-966e-35edc95b55e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f8442fe4-7e86-49b7-966e-35edc95b55e8")) {                    Plotly.newPlot(                        "f8442fe4-7e86-49b7-966e-35edc95b55e8",                        [{"mode":"lines","x":["2020-02-04T00:00:00-05:00","2020-02-05T00:00:00-05:00","2020-02-06T00:00:00-05:00","2020-02-07T00:00:00-05:00","2020-02-10T00:00:00-05:00","2020-02-11T00:00:00-05:00","2020-02-12T00:00:00-05:00","2020-02-13T00:00:00-05:00","2020-02-14T00:00:00-05:00","2020-02-18T00:00:00-05:00","2020-02-19T00:00:00-05:00","2020-02-20T00:00:00-05:00","2020-02-21T00:00:00-05:00","2020-02-24T00:00:00-05:00","2020-02-25T00:00:00-05:00","2020-02-26T00:00:00-05:00
# ...

# %%
meta = yfinance.Ticker('GOOG')
hist = meta.history(period='3y')
fig = go.Figure(data=go.Scatter(x=hist.index,y=hist['Close'], mode='lines'))
fig.show()
# Out:
# <div>                            <div id="27ea029e-3222-477e-8871-cf7072ce565c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27ea029e-3222-477e-8871-cf7072ce565c")) {                    Plotly.newPlot(                        "27ea029e-3222-477e-8871-cf7072ce565c",                        [{"mode":"lines","x":["2020-02-04T00:00:00-05:00","2020-02-05T00:00:00-05:00","2020-02-06T00:00:00-05:00","2020-02-07T00:00:00-05:00","2020-02-10T00:00:00-05:00","2020-02-11T00:00:00-05:00","2020-02-12T00:00:00-05:00","2020-02-13T00:00:00-05:00","2020-02-14T00:00:00-05:00","2020-02-18T00:00:00-05:00","2020-02-19T00:00:00-05:00","2020-02-20T00:00:00-05:00","2020-02-21T00:00:00-05:00","2020-02-24T00:00:00-05:00","2020-02-25T00:00:00-05:00","2020-02-26T00:00:00-05:00
# ...

# %%
meta = yfinance.Ticker('AAPL')
hist = meta.history(period='3y')
fig = go.Figure(data=go.Scatter(x=hist.index,y=hist['Close'], mode='lines'))
fig.show()
# Out:
# <div>                            <div id="3bbb3685-a558-4d0c-85d6-cead15fac172" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3bbb3685-a558-4d0c-85d6-cead15fac172")) {                    Plotly.newPlot(                        "3bbb3685-a558-4d0c-85d6-cead15fac172",                        [{"mode":"lines","x":["2020-02-04T00:00:00-05:00","2020-02-05T00:00:00-05:00","2020-02-06T00:00:00-05:00","2020-02-07T00:00:00-05:00","2020-02-10T00:00:00-05:00","2020-02-11T00:00:00-05:00","2020-02-12T00:00:00-05:00","2020-02-13T00:00:00-05:00","2020-02-14T00:00:00-05:00","2020-02-18T00:00:00-05:00","2020-02-19T00:00:00-05:00","2020-02-20T00:00:00-05:00","2020-02-21T00:00:00-05:00","2020-02-24T00:00:00-05:00","2020-02-25T00:00:00-05:00","2020-02-26T00:00:00-05:00
# ...

# %%
meta = yfinance.Ticker('AMZN')
hist = meta.history(period='3y')
fig = go.Figure(data=go.Scatter(x=hist.index,y=hist['Close'], mode='lines'))
fig.show()
# Out:
# <div>                            <div id="f31757a9-a314-4b81-8060-d5057b9373c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f31757a9-a314-4b81-8060-d5057b9373c3")) {                    Plotly.newPlot(                        "f31757a9-a314-4b81-8060-d5057b9373c3",                        [{"mode":"lines","x":["2020-02-04T00:00:00-05:00","2020-02-05T00:00:00-05:00","2020-02-06T00:00:00-05:00","2020-02-07T00:00:00-05:00","2020-02-10T00:00:00-05:00","2020-02-11T00:00:00-05:00","2020-02-12T00:00:00-05:00","2020-02-13T00:00:00-05:00","2020-02-14T00:00:00-05:00","2020-02-18T00:00:00-05:00","2020-02-19T00:00:00-05:00","2020-02-20T00:00:00-05:00","2020-02-21T00:00:00-05:00","2020-02-24T00:00:00-05:00","2020-02-25T00:00:00-05:00","2020-02-26T00:00:00-05:00
# ...

# %%
meta = yfinance.Ticker('MSFT')
hist = meta.history(period='3y')
fig = go.Figure(data=go.Scatter(x=hist.index,y=hist['Close'], mode='lines'))
fig.show()
# Out:
# <div>                            <div id="8bf24718-c6ca-431d-8fd9-c9f732b92211" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8bf24718-c6ca-431d-8fd9-c9f732b92211")) {                    Plotly.newPlot(                        "8bf24718-c6ca-431d-8fd9-c9f732b92211",                        [{"mode":"lines","x":["2020-02-04T00:00:00-05:00","2020-02-05T00:00:00-05:00","2020-02-06T00:00:00-05:00","2020-02-07T00:00:00-05:00","2020-02-10T00:00:00-05:00","2020-02-11T00:00:00-05:00","2020-02-12T00:00:00-05:00","2020-02-13T00:00:00-05:00","2020-02-14T00:00:00-05:00","2020-02-18T00:00:00-05:00","2020-02-19T00:00:00-05:00","2020-02-20T00:00:00-05:00","2020-02-21T00:00:00-05:00","2020-02-24T00:00:00-05:00","2020-02-25T00:00:00-05:00","2020-02-26T00:00:00-05:00
# ...

# %%
rets = daily_return.dropna()

area = np.pi * 20

plt.figure(figsize=(8, 8))
plt.scatter(daily_return.mean(), daily_return.std(), s=area)
plt.xlabel('Expected return')
plt.ylabel('Risk')
plt.grid()

for label, x, y in zip(rets.columns, daily_return.mean(), daily_return.std()):
    plt.annotate(label, xy=(x, y), xytext=(50, 50), textcoords='offset points', ha='right', va='bottom',           
    arrowprops=dict(arrowstyle='-', color='blue', connectionstyle='arc3,rad=-0.3'))

# %%
#Thesis
#Stock correlation describes the relationship that exists between two stocks and their respective price movements.
#Correlation is a widely-used concept in modern finance. For example, a trader might use historical correlations to predict whether a company’s shares will rise or fall in response to a change in interest rates or commodity prices.
#A positive correlation betwwen stocks indicates that they tend to move in the same direction. while a negative correlation means that 
#thatthey tend to move in opposite dirctions.Understanding these correlations can help investors make informed decisions about whichstocks to 
#invest in and how to allocate their portfolios.

#Stocks can be positively correlated when they move up or down in tandem. A correlation value of 1 means two stocks have a perfect positive correlation.
#If one stock moves up while the other goes down, they would have a perfect negative correlation, noted by a value of -1.
#If each stock seems to move completely independently of the other, they could be considered uncorrelated and have a value of 0.

#its important to note thatcorrelations between stocks can change over time can be affected by various market and economic factors.Hence,it is
#essential for investors to regularly monitor the correlations between stocks and adjust their portfoliosaccordingly. By doing so, they can
#minimize risk and potentially increase returns.

#Correlation heatmaps are a type of plot that visualize the strength of relationships between numerical variables.Correlation plots are used to understand which variables are related to each other and the strength of this relationship. 
#A correlation plot typically contains a number of numerical variables, with each variable represented by a column. The rows represent the relationship between each pair of variables.
#The values in the cells indicate the strength of the relationship, with positive values indicating a positive relationship and negative values indicating a negative relationship. 
#heatmap can provide a quick and initive way to understand the correlations between stocks and help investors make informed decision about their portfolios.

# From the above figure we came to know that when two variables increase together and decrease together then they are positively correlated. ‘1’ is a perfect positive correlation as shown in both the figures in yellow color diagonally.

#  Degree of Correlation-

#  i. If the value of correlation lies between ± 0.30 and ± 0.49, then it is said to be a medium correlation/ moderate correlation.

#  ii. If the coefficient value lies between ± 0.50 and ± 1, then it is said to be a strong/high correlat

#  iv. If the value is near ± 1, then it said to be a perfect correlation.

#  v. When the value is zero then there is no correlation.

#  i. Here from the graph correlation of stock return there is a moderate corrlelation between META and MSFT of 0.46

# ii. There is high correlation between GOOG and META of 0.56

# iii. When the value lies below + .29, then it is said to be a small/low correlation0
